# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/country_development_data.csv")

# %%
data = data[['Country', 'Max Latitude', 'Min Latitude', 'Max Longitude', 'Min Longitude']]

# %%
data
# Out:
#                                 Country  Max Latitude  Min Latitude  \
# 0                           Afghanistan      0.602919      0.723203
# 1                               Albania      0.639673      0.806625
# 2                               Algeria      0.590785      0.638480
# 3                                Angola      0.226062      0.337267
# 4                   Antigua and Barbuda      0.420557      0.622284
# ..                                  ...           ...           ...
# 157                             Vanuatu      0.149829      0.319199
# 158  Venezuela (Bolivarian Republic of)      0.402708      0.489298
# 159                               Yemen      0.431724      0.582567
# 160                              Zambia      0.192649      0.336941
# 161                            Zimbabwe      0.127407      0.301701
#
#      Max Longitude  Min Longitude
# 0         0.700916       0.694015
# 1         0.547690       0.575061
# 2         0.521881       0.494401
# ...

# %%
data.to_csv("../data/country_development_data.csv")
