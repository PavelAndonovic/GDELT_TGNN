# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/yearly_GDP_data.csv")

# %%
data
# Out:
#     Country Code          1960          1961          1962          1963  \
# 0            ABW           NaN           NaN           NaN           NaN
# 1            AFE  1.931311e+10  1.972349e+10  2.149392e+10  2.573321e+10
# 2            AFG  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3            AFW  1.040428e+10  1.112805e+10  1.194335e+10  1.267652e+10
# 4            AGO           NaN           NaN           NaN           NaN
# ..           ...           ...           ...           ...           ...
# 261          XKX           NaN           NaN           NaN           NaN
# 262          YEM           NaN           NaN           NaN           NaN
# 263          ZAF  7.575397e+09  7.972997e+09  8.497997e+09  9.423396e+09
# 264          ZMB  7.130000e+08  6.962857e+08  6.931429e+08  7.187143e+08
# 265          ZWE  1.052990e+09  1.096647e+09  1.117602e+09  1.159512e+09
#
#              1964          1965          1966          1967          1968  \
# ...

# %%
data = data.transpose()

# %%
new_cols = data.iloc[0]
data = data[1:]
data.columns = new_cols
data
# Out:
# Country Code           ABW              AFE            AFG             AFW  \
# 1960                   NaN    19313106302.0    537777811.1   10404280784.0
# 1961                   NaN    19723488057.0    548888895.6   11128050589.0
# 1962                   NaN    21493920015.0    546666677.8   11943353288.0
# 1963                   NaN    25733212134.0    751111191.1   12676515454.0
# 1964                   NaN    23527443251.0    800000044.4   13838577015.0
# ...                    ...              ...            ...             ...
# 2016          2983636872.0   873355000000.0  18116562465.0  690543000000.0
# 2017          3092430168.0   985356000000.0  18753469630.0  683742000000.0
# 2018          3202188607.0  1012850000000.0  18053228579.0  741692000000.0
# 2019                   NaN  1009910000000.0  18799450743.0  794572000000.0
# 2020                   NaN   920792000000.0  20116137326.0  784588000000.0
#
# ...

# %%
data = data.fillna(method="ffill")
data = data.fillna(method="bfill")

# %%
data
# Out:
# Country Code           ABW           AFE           AFG           AFW  \
# 1960          4.054634e+08  1.931311e+10  5.377778e+08  1.040428e+10
# 1961          4.054634e+08  1.972349e+10  5.488889e+08  1.112805e+10
# 1962          4.054634e+08  2.149392e+10  5.466667e+08  1.194335e+10
# 1963          4.054634e+08  2.573321e+10  7.511112e+08  1.267652e+10
# 1964          4.054634e+08  2.352744e+10  8.000000e+08  1.383858e+10
# ...                    ...           ...           ...           ...
# 2016          2.983637e+09  8.733550e+11  1.811656e+10  6.905430e+11
# 2017          3.092430e+09  9.853560e+11  1.875347e+10  6.837420e+11
# 2018          3.202189e+09  1.012850e+12  1.805323e+10  7.416920e+11
# 2019          3.202189e+09  1.009910e+12  1.879945e+10  7.945720e+11
# 2020          3.202189e+09  9.207920e+11  2.011614e+10  7.845880e+11
#
# Country Code           AGO           ALB           AND           ARB  \
# ...

# %%
data.to_csv("../data/yearly_GDP_data.csv")
